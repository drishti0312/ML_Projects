# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %% [markdown]
# Steps to perform
# 1. Pre-process + EDA +Feature Selection
# 2. Extract input and output cols
# 3. Scale the Values
# 4. Train test split (Cross Validation)
# 5. Train the model
# 6. Evaluate the model/model selection
# 7. Deploy the model

# %%
df.shape
# Out:
# (100, 4)

# %% [markdown]
# # New section

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df = df.iloc[:,1:]   # all rows and 1 onwards column

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]   # Independent values
y = df.iloc[:,-1]   # Dependent values

# %%
y.shape
# Out:
# (100,)

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 34   4.8  163.0
# 94   4.7   52.0
# 40   4.9  134.0
# 51   4.8  141.0
# 21   7.1  151.0
# ..   ...    ...
# 24   4.7  121.0
# 53   8.3  168.0
# 89   4.9  151.0
# 88   4.4  149.0
# 66   6.9   96.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 34    0
# 94    0
# 40    0
# 51    0
# 21    1
#      ..
# 24    0
# 53    1
# 89    0
# 88    0
# 66    1
# Name: placement, Length: 90, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-1.04984857,  1.06092888],
#        [-1.13840187, -1.75188415],
#        [-0.96129527,  0.3260498 ],
#        [-1.04984857,  0.5034344 ],
#        [ 0.98687734,  0.75684098],
#        [-0.96129527, -1.52381823],
#        [-0.51852877,  0.35139046],
#        [ 1.16398394, -0.13008204],
#        [ 1.25253724,  0.27536848],
#        [-0.25286887,  0.27536848],
#        [-0.78418867,  1.39035743],
#        [-0.96129527,  0.85820362],
#        [-0.69563537, -0.78893915],
#        [-0.51852877, -0.18076336],
#        [ 0.10134433,  0.27536848],
#        [ 1.60675044, -0.18076336],
#        [-0.69563537,  2.60670901],
#        [-1.40406177, -2.00529073],
#        [ 0.72121743,  0.5034344 ],
#        [ 1.34109054, -1.52381823],
#        [ 0.45555753, -2.13199402],
#        [ 0.89832403, -0.23144468],
#        [ 0.89832403,  0.45275309],
#        [ 0.54411083,  0.42741243],
#        [-0.87274197, -0.07940073],
#        [-1.84682827, -0.30746665],
#        [ 1.16398394, -0.89030178],
#        [-1.04984857,  1.21297283],
#        [-1.13840187, -0.86496112],
#        [ 1.42964384, -0.81427981],
#        [-0.69563537,  0.27536848],
#        [-1.22695517,  0.63013769],
#        [-0.87274197, -1.47313691],
#        [ 0.10134433, -1.01700507],
#        [-0.16431557,  0.52877506],
#        [ 1.34109054,  0.22468717],
#        [-2.37814808,  1.56774204],
#        [ 0.72121743, -0.23144468],
#        [-0.69563537,  1.01024756],
#        [ 0.89832403, -1.44779626],
#        [ 0.01279103, -0.48485126],
#        [-2.20104147,  2.83477493],
#        [ 1.16398394,  0.40207177],
#        [-1.75827497, -0.53553257],
#        [ 0.18989763, -0.20610402],
#        [-0.78418867,  0.17400585],
#        [-0.96129527, -0.02871941],
#        [-0.60708207, -0.00337875],
#        [-0.07576227, -0.38348862],
#        [ 0.45555753,  0.9849069 ],
#        [ 0.63266413,  0.83286296],
#        [-0.51852877, -0.35814797],
#        [ 0.27845093,  0.17400585],
#        [-0.69563537, -0.28212599],
#        [ 0.45555753,  0.22468717],
#        [ 0.36700423, -0.13008204],
#        [-0.87274197, -0.76359849],
#        [ 0.10134433,  0.88354427],
#        [ 1.16398394, -1.80256547],
#        [ 0.72121743, -0.78893915],
#        [ 0.27845093, -0.4595106 ],
#        [ 1.78385704, -1.06768639],
#        [-0.25286887,  0.47809375],
#        [ 0.10134433, -1.4224556 ],
#        [-0.60708207, -0.18076336],
#        [-0.25286887,  0.55411572],
#        [ 0.98687734, -1.85324678],
#        [ 0.01279103, -1.39711494],
#        [ 1.87241034,  1.13695085],
#        [ 0.45555753, -0.78893915],
#        [ 0.89832403,  1.36501677],
#        [ 0.54411083, -0.02871941],
#        [-1.04984857, -0.23144468],
#        [ 0.89832403,  1.97319256],
#        [-0.51852877,  0.45275309],
#        [ 0.63266413,  1.54240138],
#        [ 1.87241034,  0.70615967],
#        [-0.78418867, -1.39711494],
#        [ 0.80977073,  0.42741243],
#        [-0.16431557,  1.13695085],
#        [ 2.22662354, -0.02871941],
#        [ 0.01279103, -1.92926876],
#        [ 0.01279103,  0.70615967],
#        [ 0.10134433, -0.4595106 ],
#        [ 0.01279103,  0.07264322],
#        [-1.13840187, -0.00337875],
#        [ 2.04951694,  1.18763217],
#        [-0.96129527,  0.75684098],
#        [-1.40406177,  0.70615967],
#        [ 0.80977073, -0.6368952 ]])

# %%
X_test
# Out:
#     cgpa     iq
# 30   7.6  128.0
# 84   5.7  169.0
# 60   6.9  139.0
# 80   4.9  196.0
# 70   6.3  127.0
# 95   4.3  200.0
# 68   4.0   75.0
# 0    6.8  123.0
# 54   6.4  141.0
# 91   7.5  158.0

# %%
y_test
# Out:
# 30    1
# 84    0
# 60    1
# 80    0
# 70    1
# 95    0
# 68    0
# 0     1
# 54    1
# 91    1
# Name: placement, dtype: int64

# %%
X_train = scaler.fit_transform(X_train)
X_train
# Out:
# array([[-1.04984857,  1.06092888],
#        [-1.13840187, -1.75188415],
#        [-0.96129527,  0.3260498 ],
#        [-1.04984857,  0.5034344 ],
#        [ 0.98687734,  0.75684098],
#        [-0.96129527, -1.52381823],
#        [-0.51852877,  0.35139046],
#        [ 1.16398394, -0.13008204],
#        [ 1.25253724,  0.27536848],
#        [-0.25286887,  0.27536848],
#        [-0.78418867,  1.39035743],
#        [-0.96129527,  0.85820362],
#        [-0.69563537, -0.78893915],
#        [-0.51852877, -0.18076336],
#        [ 0.10134433,  0.27536848],
#        [ 1.60675044, -0.18076336],
#        [-0.69563537,  2.60670901],
#        [-1.40406177, -2.00529073],
#        [ 0.72121743,  0.5034344 ],
#        [ 1.34109054, -1.52381823],
#        [ 0.45555753, -2.13199402],
#        [ 0.89832403, -0.23144468],
#        [ 0.89832403,  0.45275309],
#        [ 0.54411083,  0.42741243],
#        [-0.87274197, -0.07940073],
#        [-1.84682827, -0.30746665],
#        [ 1.16398394, -0.89030178],
#        [-1.04984857,  1.21297283],
#        [-1.13840187, -0.86496112],
#        [ 1.42964384, -0.81427981],
#        [-0.69563537,  0.27536848],
#        [-1.22695517,  0.63013769],
#        [-0.87274197, -1.47313691],
#        [ 0.10134433, -1.01700507],
#        [-0.16431557,  0.52877506],
#        [ 1.34109054,  0.22468717],
#        [-2.37814808,  1.56774204],
#        [ 0.72121743, -0.23144468],
#        [-0.69563537,  1.01024756],
#        [ 0.89832403, -1.44779626],
#        [ 0.01279103, -0.48485126],
#        [-2.20104147,  2.83477493],
#        [ 1.16398394,  0.40207177],
#        [-1.75827497, -0.53553257],
#        [ 0.18989763, -0.20610402],
#        [-0.78418867,  0.17400585],
#        [-0.96129527, -0.02871941],
#        [-0.60708207, -0.00337875],
#        [-0.07576227, -0.38348862],
#        [ 0.45555753,  0.9849069 ],
#        [ 0.63266413,  0.83286296],
#        [-0.51852877, -0.35814797],
#        [ 0.27845093,  0.17400585],
#        [-0.69563537, -0.28212599],
#        [ 0.45555753,  0.22468717],
#        [ 0.36700423, -0.13008204],
#        [-0.87274197, -0.76359849],
#        [ 0.10134433,  0.88354427],
#        [ 1.16398394, -1.80256547],
#        [ 0.72121743, -0.78893915],
#        [ 0.27845093, -0.4595106 ],
#        [ 1.78385704, -1.06768639],
#        [-0.25286887,  0.47809375],
#        [ 0.10134433, -1.4224556 ],
#        [-0.60708207, -0.18076336],
#        [-0.25286887,  0.55411572],
#        [ 0.98687734, -1.85324678],
#        [ 0.01279103, -1.39711494],
#        [ 1.87241034,  1.13695085],
#        [ 0.45555753, -0.78893915],
#        [ 0.89832403,  1.36501677],
#        [ 0.54411083, -0.02871941],
#        [-1.04984857, -0.23144468],
#        [ 0.89832403,  1.97319256],
#        [-0.51852877,  0.45275309],
#        [ 0.63266413,  1.54240138],
#        [ 1.87241034,  0.70615967],
#        [-0.78418867, -1.39711494],
#        [ 0.80977073,  0.42741243],
#        [-0.16431557,  1.13695085],
#        [ 2.22662354, -0.02871941],
#        [ 0.01279103, -1.92926876],
#        [ 0.01279103,  0.70615967],
#        [ 0.10134433, -0.4595106 ],
#        [ 0.01279103,  0.07264322],
#        [-1.13840187, -0.00337875],
#        [ 2.04951694,  1.18763217],
#        [-0.96129527,  0.75684098],
#        [-1.40406177,  0.70615967],
#        [ 0.80977073, -0.6368952 ]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
