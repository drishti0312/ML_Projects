# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
#1. How big is the data?
df.shape
# Out:
# (891, 12)

# %%
#2. What type of data we have been given
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 444          445         1       3  Johannesen-Bratthammer, Mr. Bernt    male
# 301          302         1       3                 McCoy, Mr. Bernard    male
# 729          730         0       3      Ilmakangas, Miss. Pieta Sofia  female
# 253          254         0       3           Lobb, Mr. William Arthur    male
# 663          664         0       3                   Coleff, Mr. Peju    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 444   NaN      0      0             65306   8.1125   NaN        S
# 301   NaN      2      0            367226  23.2500   NaN        Q
# 729  25.0      1      0  STON/O2. 3101271   7.9250   NaN        S
# 253  30.0      1      0         A/5. 3336  16.1000   NaN        S
# 663  36.0      0      0            349210   7.4958   NaN        S

# %%
#3. Different types of data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#4. Null values in data
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#5. is there any duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#6. How does my data look mathematically?
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#7. What is the correlation between the columns
# df.corr()   Cause it cannot convert string values to numeric values 
df.corr(numeric_only=True)['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %% [markdown]
#  ## Univariante Analysis ##

# %%
###Categorical Data ####

# %%
# 1. Countplot
sns.countplot(df,x='Survived',palette='Set2')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13720\3755314341.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x='Survived',palette='Set2')
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(df, x='Pclass',palette='Set1')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13720\1254264646.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df, x='Pclass',palette='Set1')
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(df, x='Sex',palette='Set3')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13720\2261437041.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df, x='Sex',palette='Set3')
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(df, x='Embarked',palette='Set2')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13720\3242147612.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df, x='Embarked',palette='Set2')
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
#### Pie Chart ###

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # b. Numberical Data #

# %% [markdown]
# ## a. Histogram

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Distplot

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13720\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## c. Boxplot

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)
